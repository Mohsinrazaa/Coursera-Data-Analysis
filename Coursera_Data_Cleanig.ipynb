# %%
import pandas as pd
import numpy as np
coursera = pd.read_csv('coursea_data.csv')

# %%
coursera.head()
# Out:
#    Unnamed: 0                                       course_title  \
# 0         134  (ISC)² Systems Security Certified Practitioner...
# 1         743  A Crash Course in Causality:  Inferring Causal...
# 2         874                     A Crash Course in Data Science
# 3         413                            A Law Student's Toolkit
# 4         635                A Life of Happiness and Fulfillment
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# ...

# %%
coursera.tail()
# Out:
#      Unnamed: 0                                   course_title  \
# 886         236                     Программирование на Python
# 887         883           Психолингвистика (Psycholinguistics)
# 888         545   Разработка интерфейсов: вёрстка и JavaScript
# 889         875                        Русский как иностранный
# 890         163  Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 886                                      Mail.Ru Group
# 887                  Saint Petersburg State University
# 888                        E-Learning Development Fund
# 889                  Saint Petersburg State University
# 890  National Research University Higher School of ...
#
#     course_Certificate_type  course_rating course_difficulty  \
# 886          SPECIALIZATION            4.5      Intermediate
# 887                  COURSE            4.8             Mixed
# 888          SPECIALIZATION            4.5      Intermediate
# ...

# %%
coursera.shape
# Out:
# (891, 7)

# %%
coursera.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Unnamed: 0                  891 non-null int64
# course_title                891 non-null object
# course_organization         891 non-null object
# course_Certificate_type     891 non-null object
# course_rating               891 non-null float64
# course_difficulty           891 non-null object
# course_students_enrolled    891 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 31.4+ KB

# %%
coursera.columns
# Out:
# Index(['Unnamed: 0', 'course_title', 'course_organization',
#        'course_Certificate_type', 'course_rating', 'course_difficulty',
#        'course_students_enrolled'],
#       dtype='object')

# %%
column = ['course_number', 'course_title', 'course_organization',
       'course_Certificate_type', 'course_rating', 'course_difficulty',
       'course_students_enrolled']
coursera.columns = column

# %%
coursera.columns
# Out:
# Index(['course_number', 'course_title', 'course_organization',
#        'course_Certificate_type', 'course_rating', 'course_difficulty',
#        'course_students_enrolled'],
#       dtype='object')

# %%
coursera.head(3)
# Out:
#    course_number                                       course_title  \
# 0            134  (ISC)² Systems Security Certified Practitioner...
# 1            743  A Crash Course in Causality:  Inferring Causal...
# 2            874                     A Crash Course in Data Science
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# 2             Mixed                     130k

# %%
coursera.describe()
# Out:
#        course_number  course_rating
# count     891.000000     891.000000
# mean      445.000000       4.677329
# std       257.353842       0.162225
# min         0.000000       3.300000
# 25%       222.500000       4.600000
# 50%       445.000000       4.700000
# 75%       667.500000       4.800000
# max       890.000000       5.000000

# %%
coursera["course_rating"].value_counts()
# Out:
# 4.8    256
# 4.7    251
# 4.6    168
# 4.5     80
# 4.9     68
# 4.4     34
# 4.3     15
# 4.2     10
# 3.9      2
# 4.0      2
# 5.0      2
# 3.3      1
# 3.7      1
# 4.1      1
# Name: course_rating, dtype: int64

# %%
coursera["course_rating"].value_counts().plot()

# %%
coursera["course_Certificate_type"].value_counts()
# Out:
# COURSE                      582
# SPECIALIZATION              297
# PROFESSIONAL CERTIFICATE     12
# Name: course_Certificate_type, dtype: int64

# %%
coursera["course_organization"].value_counts()
# Out:
# University of Pennsylvania            59
# University of Michigan                41
# Google Cloud                          34
# Duke University                       28
# Johns Hopkins University              28
#                                       ..
# JetBrains                              1
# Eindhoven University of Technology     1
# Universitat de Barcelona               1
# Tel Aviv University                    1
# National Taiwan University             1
# Name: course_organization, Length: 154, dtype: int64

# %%
coursera["course_organization"].value_counts().plot()

# %%
coursera["course_students_enrolled"].value_counts()
# Out:
# 120k    22
# 12k     20
# 110k    20
# 22k     19
# 14k     17
#         ..
# 740k     1
# 2.9k     1
# 6.3k     1
# 830k     1
# 610k     1
# Name: course_students_enrolled, Length: 205, dtype: int64

# %%
coursera["course_difficulty"].value_counts()
# Out:
# Beginner        487
# Intermediate    198
# Mixed           187
# Advanced         19
# Name: course_difficulty, dtype: int64

# %%
coursera["course_title"].value_counts()
# Out:
# Marketing Digital                                                                 2
# Machine Learning                                                                  2
# Developing Your Musicianship                                                      2
# The Power of Microeconomics: Economic Principles in the Real World                1
# Spanish Vocabulary: Meeting People                                                1
#                                                                                  ..
# Memoir and Personal Essay: Write About Yourself                                   1
# Drug Commercialization                                                            1
# Art & Activity: Interactive Strategies for Engaging with Art                      1
# Sales Training for High Performing Teams                                          1
# A Crash Course in Causality:  Inferring Causal Effects from Observational Data    1
# Name: course_title, Length: 888, dtype: int64

# %%
coursera.loc[:,"course_title"].head(10)
# Out:
# 0    (ISC)² Systems Security Certified Practitioner...
# 1    A Crash Course in Causality:  Inferring Causal...
# 2                       A Crash Course in Data Science
# 3                              A Law Student's Toolkit
# 4                  A Life of Happiness and Fulfillment
# 5    ADHD: Everyday Strategies for Elementary Students
# 6                                      AI For Everyone
# 7                             AI For Medical Treatment
# 8                          AI Foundations for Everyone
# 9                             AI for Medical Diagnosis
# Name: course_title, dtype: object

# %%
coursera.loc[:,"course_title"].tail(10)
# Out:
# 881                Машинное обучение и анализ данных
# 882                        Основы Digital Маркетинга
# 883                Основы программирования на Python
# 884             Основы разработки на C++: белый пояс
# 885                              Погружение в Python
# 886                       Программирование на Python
# 887             Психолингвистика (Psycholinguistics)
# 888     Разработка интерфейсов: вёрстка и JavaScript
# 889                          Русский как иностранный
# 890    Финансовые инструменты для частного инвестора
# Name: course_title, dtype: object

# %%
coursera["course_organization"].unique()
# Out:
# array(['(ISC)²', 'University of Pennsylvania', 'Johns Hopkins University',
#        'Yale University', 'Indian School of Business',
#        'University at Buffalo', 'deeplearning.ai', 'IBM',
#        'Amazon Web Services', 'University of Toronto',
#        'University of California, Irvine',
#        'University of Illinois at Urbana-Champaign',
#        'University of Michigan',
#        'Universidad Nacional Autónoma de México',
#        'University of Colorado Boulder',
#        'National Research University Higher School of Economics',
#        'Google Cloud', 'Erasmus University Rotterdam', 'Duke University',
#        'University of Virginia', 'Atlassian', 'ScrumTrek',
#        'University of California San Diego', 'Stanford University',
#        'University of Colorado System', 'Copenhagen Business School',
#        'Macquarie University', 'Vanderbilt University',
#        'The University of Edinburgh',
#        'Technical University of Denmark (DTU)', 'Universidad Austral',
# ...

# %%
coursera["course_title"].unique()
# Out:
# array(['(ISC)² Systems Security Certified Practitioner (SSCP)',
#        'A Crash Course in Causality:  Inferring Causal Effects from Observational Data',
#        'A Crash Course in Data Science', "A Law Student's Toolkit",
#        'A Life of Happiness and Fulfillment',
#        'ADHD: Everyday Strategies for Elementary Students',
#        'AI For Everyone', 'AI For Medical Treatment',
#        'AI Foundations for Everyone', 'AI for Medical Diagnosis',
#        'AI for Medical Prognosis', 'AI for Medicine', 'AWS Fundamentals',
#        'AWS Fundamentals: Addressing Security Risk',
#        'AWS Fundamentals: Building Serverless Applications',
#        'AWS Fundamentals: Going Cloud-Native',
#        'AWS Fundamentals: Migrating to the Cloud',
#        'Aboriginal Worldviews and Education', 'Academic English: Writing',
#        'Accelerated Computer Science Fundamentals', 'Access Controls',
#        'Accounting Analytics', 'Accounting for Decision Making',
# ...

# %%
coursera.isnull().sum()
# Out:
# course_number               0
# course_title                0
# course_organization         0
# course_Certificate_type     0
# course_rating               0
# course_difficulty           0
# course_students_enrolled    0
# dtype: int64

# %%
coursera.isnull().sum().plot()

# %%
coursera.head()
# Out:
#    course_number                                       course_title  \
# 0            134  (ISC)² Systems Security Certified Practitioner...
# 1            743  A Crash Course in Causality:  Inferring Causal...
# 2            874                     A Crash Course in Data Science
# 3            413                            A Law Student's Toolkit
# 4            635                A Life of Happiness and Fulfillment
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# ...

# %%
japan_bool = coursera["course_organization"] == "(ISC)²"

ISC = coursera[japan_bool]

# %%
ISC.sort_values("course_rating",ascending = False).iloc[0]["course_number"]
# Out:
# 856

# %%
coursies = coursera["course_title"].unique()
coursies
# Out:
# array(['(ISC)² Systems Security Certified Practitioner (SSCP)',
#        'A Crash Course in Causality:  Inferring Causal Effects from Observational Data',
#        'A Crash Course in Data Science', "A Law Student's Toolkit",
#        'A Life of Happiness and Fulfillment',
#        'ADHD: Everyday Strategies for Elementary Students',
#        'AI For Everyone', 'AI For Medical Treatment',
#        'AI Foundations for Everyone', 'AI for Medical Diagnosis',
#        'AI for Medical Prognosis', 'AI for Medicine', 'AWS Fundamentals',
#        'AWS Fundamentals: Addressing Security Risk',
#        'AWS Fundamentals: Building Serverless Applications',
#        'AWS Fundamentals: Going Cloud-Native',
#        'AWS Fundamentals: Migrating to the Cloud',
#        'Aboriginal Worldviews and Education', 'Academic English: Writing',
#        'Accelerated Computer Science Fundamentals', 'Access Controls',
#        'Accounting Analytics', 'Accounting for Decision Making',
# ...

# %%
Top_course = {}

for course in coursies:
    mean = coursera[coursera["course_title"] == course]["course_students_enrolled"]
    Top_course[course] = mean

# %%
Top_course
# Out:
# {'(ISC)² Systems Security Certified Practitioner (SSCP)': 0    5.3k
#  Name: course_students_enrolled, dtype: object,
#  'A Crash Course in Causality:  Inferring Causal Effects from Observational Data': 1    17k
#  Name: course_students_enrolled, dtype: object,
#  'A Crash Course in Data Science': 2    130k
#  Name: course_students_enrolled, dtype: object,
#  "A Law Student's Toolkit": 3    91k
#  Name: course_students_enrolled, dtype: object,
#  'A Life of Happiness and Fulfillment': 4    320k
#  Name: course_students_enrolled, dtype: object,
#  'ADHD: Everyday Strategies for Elementary Students': 5    39k
#  Name: course_students_enrolled, dtype: object,
#  'AI For Everyone': 6    350k
#  Name: course_students_enrolled, dtype: object,
#  'AI For Medical Treatment': 7    2.4k
#  Name: course_students_enrolled, dtype: object,
#  'AI Foundations for Everyone': 8    61k
#  Name: course_students_enrolled, dtype: object,
#  'AI for Medical Diagnosis': 9    12k
# ...

# %%
course = pd.Series(Top_course)
course.head(10)
# Out:
# (ISC)² Systems Security Certified Practitioner (SSCP)                             0    5.3k
# Name: course_students_enrolled, dtyp...
# A Crash Course in Causality:  Inferring Causal Effects from Observational Data    1    17k
# Name: course_students_enrolled, dtype...
# A Crash Course in Data Science                                                    2    130k
# Name: course_students_enrolled, dtyp...
# A Law Student's Toolkit                                                           3    91k
# Name: course_students_enrolled, dtype...
# A Life of Happiness and Fulfillment                                               4    320k
# Name: course_students_enrolled, dtyp...
# ADHD: Everyday Strategies for Elementary Students                                 5    39k
# Name: course_students_enrolled, dtype...
# AI For Everyone                                                                   6    350k
# Name: course_students_enrolled, dtyp...
# ...

# %%
coursera["course_students_enrolled"].head(20)
# Out:
# 0     5.3k
# 1      17k
# 2     130k
# 3      91k
# 4     320k
# 5      39k
# 6     350k
# 7     2.4k
# 8      61k
# 9      12k
# 10      4k
# 11     13k
# 12    130k
# 13     11k
# 14     27k
# 15    110k
# 16     13k
# 17    6.6k
# 18    540k
# 19     22k
# Name: course_students_enrolled, dtype: object

# %%
coursera["course_students_enrolled"].tail(20)
# Out:
# 871    140k
# 872     17k
# 873     76k
# 874     25k
# 875    190k
# 876     69k
# 877     14k
# 878     68k
# 879     16k
# 880     67k
# 881     77k
# 882     19k
# 883     83k
# 884     41k
# 885     45k
# 886     52k
# 887     21k
# 888     30k
# 889    9.8k
# 890     38k
# Name: course_students_enrolled, dtype: object

# %%
coursera["course_students_enrolled"].unique()
# Out:
# array(['5.3k', '17k', '130k', '91k', '320k', '39k', '350k', '2.4k', '61k',
#        '12k', '4k', '13k', '11k', '27k', '110k', '6.6k', '540k', '22k',
#        '2.9k', '80k', '9.9k', '23k', '9.2k', '78k', '190k', '35k', '29k',
#        '14k', '21k', '94k', '69k', '40k', '220k', '150k', '18k', '270k',
#        '7.9k', '30k', '36k', '20k', '8.1k', '120k', '71k', '63k', '42k',
#        '480k', '97k', '200k', '180k', '4.2k', '310k', '3.9k', '79k',
#        '31k', '15k', '10k', '66k', '33k', '56k', '7.3k', '9.7k', '210k',
#        '28k', '6.5k', '55k', '2.3k', '8.8k', '88k', '1.9k', '68k', '1.6k',
#        '9.5k', '57k', '26k', '84k', '95k', '5.8k', '24k', '67k', '280k',
#        '38k', '77k', '510k', '89k', '48k', '160k', '32k', '340k', '82k',
#        '790k', '19k', '51k', '4.8k', '37k', '43k', '6.4k', '49k', '240k',
#        '46k', '7.8k', '75k', '81k', '140k', '5.5k', '99k', '100k', '3k',
#        '830k', '740k', '60k', '96k', '690k', '44k', '4.5k', '8.2k', '16k',
# ...

# %%
coursera["course_students_enrolled"].value_counts().head(16)
# Out:
# 120k    22
# 12k     20
# 110k    20
# 22k     19
# 14k     17
# 23k     16
# 140k    16
# 150k    14
# 220k    14
# 130k    14
# 16k     13
# 10k     12
# 17k     12
# 39k     12
# 34k     11
# 11k     11
# Name: course_students_enrolled, dtype: int64

# %%
# Out:
# 7.6k    1
# 790k    1
# 6.1k    1
# 7.1k    1
# 1.5m    1
# 630k    1
# 330k    1
# 7.8k    1
# 390k    1
# 750k    1
# 8.2k    1
# 340k    1
# 3.5k    1
# 96k     1
# 2.3k    1
# 740k    1
# 2.9k    1
# 6.3k    1
# 830k    1
# 610k    1
# Name: course_students_enrolled, dtype: int64
